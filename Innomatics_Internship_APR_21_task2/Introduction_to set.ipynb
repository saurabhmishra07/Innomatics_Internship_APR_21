# %%
def average(array):
    
    a=sum(set(array))
    b=len(set(array))
    c=a/b
    return c 

if __name__ == '__main__':
    n = int(input("Enter the number"))
    arr = list(map(int, input("Enter the array").split()))
    result = average(arr)
    print(result)

# %% [markdown]
# ###### 5
