# %%
a = int(input())
x= set(map(int, input().split()))
b = int(input())
y = set(map(int, input().split()))
z = x.symmetric_difference(y)
output = sorted(list(z))
for i in output:
    print(i)
# Out:
#  5
#  6
#  5
#  4
# 4
# 6

# %% [markdown]
# ###### 5
