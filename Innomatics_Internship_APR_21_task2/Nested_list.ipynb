# %%
list1=[];
for i in range(int(input("Enter the number"))):
        name = input("Enter the name")
        score = float(input("Enter the Floating number"))
        list1.append([name, score])
highest_2 = sorted(set([score for name, score in list1]))[1]
print('\n'.join(sorted([name for name, score in list1 if score ==highest_2])))
# Out:
# Enter the number 5
# Enter the name saurabh
# Enter the Floating number 1.4
# Enter the name kamal
# Enter the Floating number 2.4
# Enter the name sam
# Enter the Floating number 3.6
# Enter the name rohan
# Enter the Floating number 4.8
# Enter the name mukesh
# Enter the Floating number 5.9
# kamal

# %%
5
