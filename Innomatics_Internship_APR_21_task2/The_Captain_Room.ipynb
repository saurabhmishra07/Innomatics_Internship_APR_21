# %%
a= input("Enter the number")
set1= set() 
set2=set()
for i in (input("Enter the number").split()):
    if i not in set1:
        set1.add(i)
    else:
        set2.add(i)
set1.difference_update(set2)
print(set1.pop())
