# %%
n,m=set(map(int,input("enter the number").split()))
n=input("Enter the number").split()
a=input("Enter the number").split()
b=input("Enter the number").split()
sum=0
for i in n:
    if(i in a):
        sum=sum+1
    elif(i in b):
        sum=sum-1
    else:
        pass
print(sum)
