# %%
A=int(input("enter the number"))
n=set(map(int,input("Enter the set").split()))
N=int(input("Enter the number"))
for i in range(N):
    a = input("Write").split()
    opt = a[0]
    s = set(map(int,input("Write a set").split()))
    if (opt == 'update'):
        n |= s
    elif (opt == 'intersection_update'):
        n &= s
    elif (opt == 'difference_update'):
        n -= s
    elif (opt == 'symmetric_difference_update'):
        n ^= s
print(sum(n))
