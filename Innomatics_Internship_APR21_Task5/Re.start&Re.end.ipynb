# %%
S = input("Enter the Strings")
k = input("Enter the Strings")
check = False
for i in range(len(S)-len(k)+1):
    if S[i:i+len(k)]==k:
        check = True
        print("({}, {})".format(i,i+len(k)-1))
if check==False:
    print("(-1, -1)")
# Out:
# Enter the Strings aaadaa
# Enter the Strings aa
# (0, 1)
# (1, 2)
# (4, 5)
