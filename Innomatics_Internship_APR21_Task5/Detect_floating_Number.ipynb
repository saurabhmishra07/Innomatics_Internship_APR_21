# %%
count=int(input("Enter the number").strip())
for i in range(count):
    ans=False
    try:
        string=input("Enter the String").strip()
        number=float(string)
        ans=True
        number=int(string)
        ans=False
    except:
        pass
    print(ans)
# Out:
#  5
#  6
# False
