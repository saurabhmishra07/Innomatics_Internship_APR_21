# %%
import re

for i in range(int(input())):
    input1 = ("  ")
    input1 = re.sub(r'(?<= )\&\&(?= )','and',input())
    input1 = re.sub(r'(?<= )\|\|(?= )','or',input1)
    print(input1)
# Out:
# Enter the Strings aaadaa
# Enter the Strings aa
# (0, 1)
# (1, 2)
# (4, 5)
