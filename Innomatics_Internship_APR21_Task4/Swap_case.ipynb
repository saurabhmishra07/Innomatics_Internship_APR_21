# %%
s=input("Enter the Letters")
def swap_case(s):
    return s.swapcase()
result=swap_case(s)
print(result)
# Out:
# Enter the Letters HackerRank.com presents "Pythonist 2".
# hACKERrANK.COM PRESENTS "pYTHONIST 2".
