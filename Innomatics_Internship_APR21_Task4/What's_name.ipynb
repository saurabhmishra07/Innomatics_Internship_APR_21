# %%
first=input("enter the first name")
last=input("enter the second name")
def Full_name(first,last):
    print(f"Hello {first} {last}! You just delved into python.")
fullname=Full_name(first,last)
print(fullname)
# Out:
# enter the first name saurqbh
# enter the second name mishra
# Hello saurqbh mishra! You just delved into python.
# None
