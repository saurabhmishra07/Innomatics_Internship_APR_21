# %%
def minion_game(string):
    player1 = 0;
    player2 = 0;
    len1 = len(string)
    for i in range(len1):
        if s[i] in "AEIOU":
            player1 += (len1)-i
        else :
            player2 += (len1)-i
    
    if player1 > player2:
        print("Kevin", player1)
    elif player1 < player2:
        print("Stuart",player2)
    elif player1 == player2:
        print("Draw")
    else :
        print("Draw")

if __name__ == '__main__':
    s = input()
    minion_game(s)
# Out:
#  BANANA
# Stuart 12
