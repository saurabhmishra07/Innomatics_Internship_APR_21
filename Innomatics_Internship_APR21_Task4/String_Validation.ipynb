# %%
s = input("Enter the list")
newList = [[i.isalnum(), i.isalpha(), i.isdigit(), i.islower(), i.isupper()] for i in s]
rotated = list(zip(*newList))
print ("\n".join([str(any(i)) for i in rotated]))
